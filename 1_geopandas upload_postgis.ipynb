# %%
from sqlalchemy import create_engine, MetaData
import geopandas as gpd

## Connect to the Database 
conf ={
  'host':"x",
  'port':'x',
  'database':"x",
  'user':"x",
  'password':"x"
}
# Run Engine
engine = create_engine("postgresql://{user}:{password}@{host}:{port}/{database}".format(**conf))

# Reflect the database tables
metadata = MetaData()
metadata.reflect(bind=engine)
# Print the table names
print("Existing tables:")
for table in metadata.tables.values():
  print(table.name)

# %%
zipfile = r"X:\work\ingestados\Biomas_250mil_4326.zip"
gdf = gpd.read_file(zipfile, engine="pyogrio")
crs = "EPSG:4326"  # Exemplo: WGS 84
gdf = gdf.to_crs(crs)

## Load shapefile to the database
gdf.to_postgis(
    con=engine,
    schema='public',
    name='biomas_br',
    index=False,
    if_exists='replace',
    chunksize=1000
    )

# %%
zipfile = r"X:\work\ingestados\assentamentos_br.zip"
gdf = gpd.read_file(zipfile, engine="pyogrio")
crs = "EPSG:4326"  # Exemplo: WGS 84
gdf = gdf.to_crs(crs)
# Filtrar geometrias nulas
gdf = gdf[gdf['geometry'].notnull()]

## Load shapefile to the database
gdf.to_postgis(
    con=engine,
    schema='public',
    name='assentamentos_br',
    index=False,
    if_exists='replace',
    chunksize=1000
    )

# %%
zipfile = r"X:\work\ingestados\quilombos_br.zip"
gdf = gpd.read_file(zipfile, engine="pyogrio")
crs = "EPSG:4326"  # Exemplo: WGS 84
gdf = gdf.to_crs(crs)
# Filtrar geometrias nulas
gdf = gdf[gdf['geometry'].notnull()]

## Load shapefile to the database
gdf.to_postgis(
    con=engine,
    schema='public',
    name='quilombos_br',
    index=False,
    if_exists='replace',
    chunksize=1000
    )

# %%
zipfile = r"X:\work\ingestados\BR_Municipios_2022_4326.zip"
gdf = gpd.read_file(zipfile, engine="pyogrio")
crs = "EPSG:4326"  # Exemplo: WGS 84
gdf = gdf.to_crs(crs)

## Load shapefile to the database
gdf.to_postgis(
    con=engine,
    schema='public',
    name='br_municipios_2022',
    index=False,
    if_exists='replace',
    chunksize=1000
    )

# %%
zipfile = r"C:\Users\guilh\Downloads\tis_poligonais.zip"
gdf = gpd.read_file(zipfile, engine="pyogrio")
gdf = gdf.to_crs(crs)

## Load shapefile to the database
gdf.to_postgis(
    con=engine,
    schema='public',
    name='tis_poligonal',
    if_exists='append',
    chunksize=1000
    )

# %%
zipfile = r"C:\Users\guilh\Downloads\Imóvel certificado SNCI Brasil.zip"
gdf = gpd.read_file(zipfile, engine="pyogrio")
crs = "EPSG:4326"  # Exemplo: WGS 84
gdf = gdf.set_crs(crs)

## Load shapefile to the database
gdf.to_postgis(
    con=engine,
    schema='public',
    name='snci_br',
    if_exists='append',
    chunksize=1000
    )

# %%
gdf = gpd.read_file(r"C:\Users\guilh\Downloads\Sigef Brasil.zip", engine="pyogrio")
crs = "EPSG:4326"  # Exemplo: WGS 84
gdf = gdf.set_crs(crs)

## Load shapefile to the database
gdf.to_postgis(
    con=engine,
    schema='public',
    name='sigef',
    if_exists='append',
    chunksize=10000
    )

# %%
gdf = gpd.read_file(r"C:\Users\guilh\Downloads\LimiteUCsFederais_26122023_a.zip", engine="pyogrio")
crs = "EPSG:4326"  # Exemplo: WGS 84
#gdf = gdf.set_crs(crs)
gdf = gdf.to_crs(crs)

## Load shapefile to the database
gdf.to_postgis(
    con=engine,
    schema='public',
    name='limite_uc',
    if_exists='append',
    chunksize=10000
    )

# %%
gdf = gpd.read_file(r"C:\Users\guilh\Downloads\embargos_icmbio_atualizado_16022024.zip")
crs = "EPSG:4326"  # Exemplo: WGS 84
gdf = gdf.to_crs(crs)

## Load shapefile to the database
gdf.to_postgis(
    con=engine,
    schema='public',
    name='embargos_icmbio',
    if_exists='append',
    chunksize=10000
    )

# %%
gdf = gpd.read_file(r"C:\Users\guilh\Downloads\geom_area.zip", engine="pyogrio")
crs = "EPSG:4326"  # Exemplo: WGS 84
gdf = gdf.to_crs(crs)

## Load shapefile to the database
gdf.to_postgis(
    con=engine,
    schema='public',
    name='geom',
    if_exists='append',
    chunksize=10000
    )

# %%
gdf = gpd.read_file(r"C:\Users\guilh\Downloads\geol_area.zip", engine="pyogrio")
crs = "EPSG:4326"  # Exemplo: WGS 84
gdf = gdf.to_crs(crs)

## Load shapefile to the database
gdf.to_postgis(
    con=engine,
    schema='public',
    name='geol',
    if_exists='append',
    chunksize=10000
    )

# %%
gdf = gpd.read_file(r"C:\Users\guilh\Downloads\pedo_area.zip", engine="pyogrio")
crs = "EPSG:4326"  # Exemplo: WGS 84
gdf = gdf.to_crs(crs)

## Load shapefile to the database
gdf.to_postgis(
    con=engine,
    schema='public',
    name='pedo',
    if_exists='append',
    chunksize=10000
    )

# %%
gdf = gpd.read_file(r"C:\Users\guilh\Downloads\vege_area.zip", engine="pyogrio")
crs = "EPSG:4326"  # Exemplo: WGS 84
gdf = gdf.to_crs(crs)

## Load shapefile to the database
gdf.to_postgis(
    con=engine,
    schema='public',
    name='vegetacao',
    if_exists='append',
    chunksize=10000
    )

# %%
gdf = gpd.read_file(r"C:\Users\guilh\Downloads\focos_qmd_inpe_2023-01-01_2023-12-31.zip", engine="pyogrio")
crs = "EPSG:4326"  # Exemplo: WGS 84
gdf = gdf.set_crs(crs)
## Load shapefile to the database
gdf.to_postgis(
    con=engine,
    schema='public',
    name='focos_qmd_2023',
    if_exists='append',
    chunksize=10000
    )

# %%
gdf = gpd.read_file(r"C:\Users\guilh\Downloads\yearly_deforestation_mataatlantica.zip", engine="pyogrio")
crs = "EPSG:4326"  # Exemplo: WGS 84
gdf = gdf.to_crs(crs)

## Load shapefile to the database
gdf.to_postgis(
    con=engine,
    schema='public',
    name='prodes_ma',
    if_exists='append',
    chunksize=10000
    )

# %%
# CAR Ingestion
from itertools import count
def ingest_chunk(gdf, engine, schema_name, table_name):
	schema_name = None
	
	if not gdf.empty:
		# try to ingest the data    
		try:
			# GeoDataFrame to PostGIS
			gdf.to_postgis(
				con=engine,
				schema=schema_name,
				name=table_name,
				if_exists='append'
			)
			
			return len(gdf)

		except Exception as e:
			logger.error(f"Failed to ingest data to DB! \n {e}")
			raise Exception(f"Failed to ingest data to DB! \n {e}")
			return 0
	else:
		logger.info("Skipping we don't have new data!")
		return 0

gdf_p = r"X:\work\car.gdb"
table_name = 'car'
schema_name= 'car'
chunk_size=50000
total_rows = 0
for i in count(start=0):

	gdf = gpd.read_file(gdf_p, driver='FileGDB', rows=slice(chunk_size*i, chunk_size*(i+1)))
	if len(gdf) == 0:
		print(f"Total rows ingested: {total_rows}")
		break
	num_rows = ingest_chunk(gdf, engine, schema_name, table_name)
	total_rows += num_rows
	del gdf

# %%
# Deprecated
import geopandas as gpd
from sqlalchemy import create_engine
import pandas as pd
import gc

# Function to read data from PostGIS in chunks
def read_postgis_chunks(table_name, db_connection_str, chunksize=1000):
    engine = create_engine(db_connection_str)
    chunks = pd.read_sql_table(table_name, con=engine, chunksize=chunksize)
    return chunks

# Function to write data to PostGIS in chunks
def write_postgis_chunks(gdf, table_name, db_connection_str, chunksize=1000):
    engine = create_engine(db_connection_str)
    for i, chunk in enumerate(gdf.groupby(gdf.index // chunksize)):
        chunk.to_postgis(table_name, engine, if_exists='append', index=False, chunksize=chunksize)
        # Clean up memory after each chunk
        del chunk
        gc.collect()

# Example usage
gdb_path = r"C:\Users\guilh\Downloads\car.gdb"
table_name = 'car'

# Step 1: Read the GDB file in chunks using GeoPandas
chunks_reader = gpd.read_file(gdb_path, driver='FileGDB', chunksize=1000)

# Step 2: Write each chunk to PostGIS
for chunk in chunks_reader:
    write_postgis_chunks(chunk, table_name, engine)
    # Clean up memory after writing each chunk
    del chunk
    gc.collect()

print("Data successfully added to PostGIS.")
